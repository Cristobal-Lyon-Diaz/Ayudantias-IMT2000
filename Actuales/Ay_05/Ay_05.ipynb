# %% [markdown]
# # Ayudantía 5

# %% [markdown]
# # Repaso

# %% [markdown]
# ## ¿Qué son las variables?
#
# En Python, una variable es un contenedor que se utiliza para almacenar valores. Los valores pueden ser números, cadenas de texto, listas, diccionarios, entre otros tipos de datos.
#
# ## Declaración y asignación de variables
#
# Para crear una variable en Python, es necesario declararla y asignarle un valor. Por ejemplo, para crear una variable llamada "edad" y asignarle el valor de 30, se puede hacer lo siguiente:

# %%
year = 2026
month = 9
day = 21

# %% [markdown]
# En este caso, "year" es el nombre de la variable y 2026 es el valor asignado. La variable "month" ahora contiene el valor de 9, de igual forma se entiende para las otras variables.
#
# ## Tipos de datos
#
# Python tiene varios tipos de datos que se pueden asignar a una variable, incluyendo:
#
# - Números enteros (`int`)
# - Números de punto flotante (`float`)
# - Cadenas de texto (`str`)
# - Booleanos (`bool`)
# - Listas (`list`)
# - Diccionarios (`dict`)
#
# Para conocer el tipo de datos de una variable, se puede utilizar la función `type()`. Por ejemplo:

# %%
nombre = "Agustina"
edad = 30
pi = 3.1416

print(type(nombre)) 
print(type(edad)) 
print(type(pi))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>

# %% [markdown]
# ## Operaciones con variables
#
# Las variables pueden ser utilizadas en operaciones matemáticas y lógicas. Por ejemplo:

# %%
a = 10
b = 5

suma = a + b
resta = a - b
multiplicacion = a * b
division = a / b
modulo = a % b
potencia = a ** b

print(suma) # Output: 15
print(resta) # Output: 5
print(multiplicacion) # Output: 50
print(division) # Output: 2.0
print(modulo) # Output: 0
print(potencia) # Output: 100000
# Out:
# 15
# 5
# 50
# 2.0
# 0
# 100000

# %% [markdown]
# ## Uso de variables string en Python
#
# Las variables string son una de las formas más comunes de almacenar texto en Python. En este notebook, veremos cómo crear y manipular variables string en Python.
# Creando variables string
#
# Para crear una variable string en Python, simplemente asignamos un valor entre comillas a una variable:

# %%
mensaje = "Hola, ¿cómo estás?"
mensaje = 'Hola, ¿cómo estás?'

# %% [markdown]
# ## Concatenando variables string
#
# Podemos concatenar dos o más variables string simplemente utilizando el operador +:

# %%
nombre = "Juan"
apellido = "Pérez"
nombre_completo = nombre + " " + apellido

nombre_completo

# %% [markdown]
# En el ejemplo anterior, la variable ``nombre_completo`` tendrá el valor "Juan Pérez".
# Accediendo a caracteres específicos
#
# Podemos acceder a caracteres específicos en una variable string utilizando la sintaxis [n], donde n es el índice del carácter que queremos acceder. Es importante tener en cuenta que los índices en Python comienzan en 0.
#
# Por ejemplo, si queremos acceder al primer carácter de una variable string, podemos hacer lo siguiente:

# %%
mensaje = "Hola, ¿cómo estás?"
primer_caracter = mensaje[0]

primer_caracter

# %% [markdown]
# En este caso, la variable `primer_caracter` tendrá el valor "H".
#
# También podemos acceder a caracteres contando hacia atrás desde el final de la cadena utilizando índices negativos. Por ejemplo, si queremos acceder al último carácter de una variable string, podemos hacer lo siguiente:

# %%
mensaje = "Hola, ¿cómo estás?"
ultimo_caracter = mensaje[-1]

ultimo_caracter

# %% [markdown]
# En este caso, la variable ``ultimo_caracter`` tendrá el valor "?".
# Obtener una subcadena
#
# Podemos obtener una subcadena de una variable string utilizando la sintaxis [n:m], donde n es el índice del primer carácter que queremos incluir en la subcadena, y m es el índice del primer carácter que queremos excluir de la subcadena.
#
# Por ejemplo, si queremos obtener la subcadena "cómo" de la variable ``mensaje``, podemos hacer lo siguiente:

# %%
mensaje = "Hola, ¿cómo estás?"
subcadena = mensaje[7:11]

subcadena

# %% [markdown]
# # Ejemplo de if, else y elif
#
# En este ejemplo, se mostrará cómo utilizar las estructuras de control de flujo `if`, `else` y `elif` en Python. La idea es mostrar cómo estas estructuras pueden ser utilizadas para controlar el flujo de un programa en función de ciertas condiciones.
#
# ## if
#
# La estructura `if` se utiliza para ejecutar un bloque de código si una condición es verdadera. La sintaxis es la siguiente:
#
# ```python
# if condicion:
#     # Código a ejecutar si la condición es verdadera

# %% [markdown]
# Por ejemplo, supongamos que queremos escribir un programa que verifique si un número es par o impar. La condición para saber si un número es par es que su resto al ser dividido por 2 sea 0. El código sería el siguiente:

# %% [markdown]
# ## else
#
# La estructura `else` se utiliza para ejecutar un bloque de código si la condición de un `if` no es verdadera. La sintaxis es la siguiente:
#
# ```python
#
# if condicion1:
#     # Código a ejecutar si la condición1 es verdadera
# elif condicion2:
#     # Código a ejecutar si la condicion2 es verdadera
# else:
#     # Código a ejecutar si ninguna de las condiciones anteriores es verdadera

# %% [markdown]
# Por ejemplo, si queremos modificar el código anterior para que también muestre si el número es impar, podemos utilizar la estructura `else` de la siguiente manera:

# %%
numero = 5

if numero % 2 == 0:
    print("El número es divisible por 2")
elif numero % 3 == 0:
    print("El número es divisible por 3")
else:
    print("El número no es divisible ni por 2 ni por 3")

# %% [markdown]
# En este caso, como el número 5 no es divisible por 2 ni por 3, se ejecuta el bloque `else`.

# %% [markdown]
# # Loops ``for`` y ``while`` en Python
#
# Los bucles ``for`` y ``while`` son estructuras de control de flujo que permiten repetir un bloque de código varias veces. En ``Python``, el bucle for se utiliza para iterar sobre una ``secuencia`` (como una ``lista`` o una ``tupla``) o una ``colección`` (como un ``diccionario`` o un ``conjunto``), mientras que el bucle ``while`` se utiliza para repetir un bloque de código mientras se cumple una determinada condición.
#
# ### El bucle ``for``
#
# La sintaxis del bucle for en ``Python`` es la siguiente:
#
# ```py
#
# for variable in secuencia:
#     # Código a ejecutar

# %% [markdown]
# Donde ``variable`` es una variable que se asigna a cada elemento de la ``secuencia`` en cada ``iteración`` del bucle. El bloque de código que se encuentra indentado después de los dos puntos ``:`` se ejecutará una vez para cada elemento de la secuencia.
#
# Por ejemplo, podemos utilizar un bucle ``for`` para ``iterar`` sobre una lista de números y mostrar cada número por pantalla:

# %%
numbers = [1, 2, 3, 4, 5]
for number in numbers:
    print(number)

# %% [markdown]
# También podemos utilizar la función ``range()`` para generar una ``secuencia`` de números y utilizarla en un bucle ``for``. La sintaxis de la función ``range()`` es la siguiente:
#
# ```py
#
# range([start], stop[, step])

# %% [markdown]
# Donde ``start`` es el número inicial de la secuencia (por defecto es ``0``), ``stop`` es el número final de la secuencia (no se incluye en la secuencia) y ``step`` es el tamaño del paso entre cada número (por defecto es 1). Por ejemplo, podemos utilizar un bucle ``for`` y la función ``range()`` para mostrar los números del 1 al 10:

# %%
for i in range(1, 11):
    print(i)

# %% [markdown]
# el bucle ``for`` se puede utilizar para iterar sobre una variedad de ``secuencias``. Algunas de las ``secuencias`` comunes que se pueden utilizar con el bucle ``for`` son:
#
# - ``Listas``: una ``lista`` es una colección ordenada y mutable de elementos. Se puede utilizar un bucle ``for`` para iterar sobre cada elemento de la ``lista`` en el orden en que aparecen. Por ejemplo:

# %%
numbers = [1, 2, 3, 4, 5]
for number in numbers:
    print(number)

# %% [markdown]
# - ```Strings```: un ``string`` es una secuencia de caracteres. Se puede utilizar un bucle ``for`` para iterar sobre cada carácter de la cadena. Por ejemplo:

# %%
word = "hello"
for letter in word:
    print(letter)

# %% [markdown]
# - ``Rangos``: un ``rango`` es una secuencia inmutable de números enteros. Se puede utilizar un bucle ``for`` para iterar sobre cada número en el rango. Por ejemplo:

# %%
for i in range(1, 6):
    print(i)

# %% [markdown]
# ### El bucle ``while``
#
# La sintaxis del bucle ``while`` en ``Python`` es la siguiente:
#
# ```py
#
# while condición:
#     # Código a ejecutar

# %% [markdown]
# Donde ``condición`` es una expresión ``booleana`` que se evalúa ``antes`` de cada ``iteración`` del bucle. El bloque de código que se encuentra ``indentado`` después de los dos puntos ``:`` se ejecutará mientras la condición sea verdadera.
#
# Por ejemplo, podemos utilizar un bucle ``while`` para mostrar los números del 1 al 10:

# %%
i = 1
while i <= 10:
    print(i)
    i += 1

# %% [markdown]
# Es importante tener cuidado al utilizar un bucle ``while``, ya que si la condición nunca se cumple, el bucle se ejecutará indefinidamente y podría hacer que el programa se bloquee o que consuma una gran cantidad de recursos del sistema.

# %% [markdown]
# ### La función ``len()``
#
# La función ``len()`` es una función incorporada en ``Python`` que se utiliza para devolver la longitud (```lenght```) de una ``secuencia``, es decir, el número de elementos que contiene. La sintaxis de la función ``len()`` es la siguiente:
#
# ```python
#
# len(secuencia)

# %% [markdown]
# Donde secuencia es la ``secuencia`` para la cual se desea obtener la longitud. La secuencia puede ser una ``lista``, una ``tupla``, una ``string``, un ``rango`` o cualquier otra secuencia.
#
# Aquí hay algunos ejemplos de cómo usar la función ``len()`` en ``Python``:

# %%
numbers = [1, 2, 3, 4, 5]
length = len(numbers)
print(length)  # Output: 5

word = "hello"
length = len(word)
print(length)  # Output: 5

t = (1, 2, 3, 4, 5)
length = len(t)
print(length)  # Output: 5

r = range(1, 6)
length = len(r)
print(length)  # Output: 5

# %% [markdown]
# En estos ejemplos, la función ``len()`` se utiliza para obtener la longitud de diferentes secuencias, como una ``lista``, una ``string``, una ``tupla`` y un ``rango``.
#
# La función ``len()`` puede ser muy útil para iterar sobre una secuencia utilizando un bucle ``for``. Por ejemplo, si queremos imprimir cada elemento de una lista en una línea separada, podemos usar un bucle ``for`` junto con la función len() de esta manera:

# %%
numbers = [1, 2, 3, 4, 5]
for i in range(len(numbers)):
    print(numbers[i])

# %% [markdown]
# # Ejercicio guiado (25%)

# %% [markdown]
# ## Introducción
# ¡Llega el DCCHackathon 2026! Te toca ser el/la encargado/a del control de acceso, así que necesitas programar una máquina validadora de credenciales.
#
# ## Objetivo
# Deberás verificar que una credencial (un int) sea válida, según las siguientes reglas:
#
# Para ver si una credencial es válida, deberás calcular su división entera por 3, de forma repetida hasta llegar a un número de un solo dígito (por ejemplo, 243 -> 81 -> 27 -> 9), y sumar los últimos dígitos de cada resultado, **incluyendo el número original** (para el ejemplo anterior, sería 3+1+7+9 = 20). Si la suma resultante es múltiplo de 4, la credencial es válida. De lo contrario, es inválida.
#
# ## Input Format
# Un int con el código de la credencial.
#
# ## Output Format
# Deberás imprimir todos los últimos dígitos del procedimiento, además del string 'Valido' o 'Invalido' (tildes omitidas intencionalmente), dependiendo de si el código es válido o no.
#
# ## Consideraciones
# * El código de la credencial siempre será un número positivo de dos dígitos o más.
#
# ## Ejemplo 1
#
# Input
# ```
# 20
# ```
#
# Output
# ```
# 0
# 6
# Invalido
# ```
#
# Explicación
# Las divisiones enteras empezando desde 20 son 20->6 (nos detenemos pues 6 tiene un solo dígito). Al sumar los últimos dígitos de cada número (0+6) nos da 6, que al no ser divisible por 4 nos dice que la credencial es inválida.
#
# ## Ejemplo 2
#
# Input
# ```
# 243
# ```
#
# Output
# ```
# 3
# 1
# 7
# 9
# Valido
# ```
#
# Explicación
# Las divisiones enteras empezando desde 243 son 243->81->27->9. Al sumar los últimos dígitos de cada uno de estos números (3+1+7+9) nos da 20, el cual sí es divisible por 4 y, por lo tanto, la credencial es válida.

# %% [markdown]
# # Ejercicio individual (75%)

# %% [markdown]
# # 4 Ejercicios — Validador de Códigos (Parte 1, versión por area)
#
# Los cuatro comparten el mismo esqueleto algorítmico del ticket original: se parte del número, se calcula su división entera de forma repetida hasta llegar a un número de un solo dígito, se imprime el último dígito de cada resultado (incluyendo el número original), y se suman para chequear un criterio de divisibilidad.
#
# Tienen que elegir solo 1 de las siguientes 4 preguntas.
#
# ---
#
# ## 1. Teatro — Validador de Entradas para el Ciclo de Teatro UC
#
# ### Introducción
# El Departamento de Teatro UC organiza su Ciclo de Otoño y tú estás a cargo de la boletería. Cada entrada tiene un código numérico que debes validar antes de dejar pasar al público.
#
# ### Objetivo
# Verifica que un código de entrada (un int) sea válido: calcula su división entera por **2**, de forma repetida hasta llegar a un número de un solo dígito, y suma los últimos dígitos de cada resultado (incluyendo el número original). Si la suma es múltiplo de **5**, la entrada es válida.
#
# ### Input Format
# Un int con el código de la entrada.
#
# ### Output Format
# Imprime todos los últimos dígitos del procedimiento, y luego 'Valido' o 'Invalido'.
#
# ### Consideraciones
# * El código siempre será un número positivo de dos dígitos o más.
#
# ### Ejemplo 1
# Input
# ```
# 12
# ```
# Output
# ```
# 2
# 6
# Invalido
# ```
# Explicación
# 12 → 6. Últimos dígitos: 2, 6. Suma = 8, no es múltiplo de 5 → Invalido.
#
# ### Ejemplo 2
# Input
# ```
# 64
# ```
# Output
# ```
# 4
# 2
# 6
# 8
# Valido
# ```
# Explicación
# 64 → 32 → 16 → 8. Últimos dígitos: 4, 2, 6, 8. Suma = 20, múltiplo de 5 → Valido.
#
# ---
#
# ## 2. Diseño — Validador de Códigos de Estampado
#
# ### Introducción
# Trabajas en el taller de serigrafía de la Facultad de Diseño y cada rollo de tela viene con un código de lote que hay que validar antes de estampar.
#
# ### Objetivo
# Verifica que un código de lote (un int) sea válido: calcula su división entera por **3**, de forma repetida hasta llegar a un número de un solo dígito, y suma los últimos dígitos de cada resultado. Si la suma es **par**, el lote es válido.
#
# ### Input Format
# Un int con el código del lote.
#
# ### Output Format
# Imprime todos los últimos dígitos del procedimiento, y luego 'Valido' o 'Invalido'.
#
# ### Consideraciones
# * El código siempre será un número positivo de dos dígitos o más.
#
# ### Ejemplo 1
# Input
# ```
# 100
# ```
# Output
# ```
# 0
# 3
# 1
# 3
# Invalido
# ```
# Explicación
# 100 → 33 → 11 → 3. Últimos dígitos: 0, 3, 1, 3. Suma = 7, impar → Invalido.
#
# ### Ejemplo 2
# Input
# ```
# 54
# ```
# Output
# ```
# 4
# 8
# 6
# Valido
# ```
# Explicación
# 54 → 18 → 6. Últimos dígitos: 4, 8, 6. Suma = 18, par → Valido.
#
# ---
#
# ## 3. Historia — Validador de Códigos de Catalogación de Manuscritos
#
# ### Introducción
# Trabajas en el Archivo Histórico y cada manuscrito recién donado llega con un código de catalogación provisorio que debes validar antes de ingresarlo al sistema.
#
# ### Objetivo
# Verifica que un código de catalogación (un int) sea válido: calcula su división entera por **2**, de forma repetida hasta llegar a un número de un solo dígito, y suma los últimos dígitos de cada resultado. Si la suma es múltiplo de **3**, el código es válido.
#
# ### Input Format
# Un int con el código de catalogación.
#
# ### Output Format
# Imprime todos los últimos dígitos del procedimiento, y luego 'Valido' o 'Invalido'.
#
# ### Consideraciones
# * El código siempre será un número positivo de dos dígitos o más.
#
# ### Ejemplo 1
# Input
# ```
# 40
# ```
# Output
# ```
# 0
# 0
# 0
# 5
# Invalido
# ```
# Explicación
# 40 → 20 → 10 → 5. Últimos dígitos: 0, 0, 0, 5. Suma = 5, no es múltiplo de 3 → Invalido.
#
# ### Ejemplo 2
# Input
# ```
# 24
# ```
# Output
# ```
# 4
# 2
# 6
# Valido
# ```
# Explicación
# 24 → 12 → 6. Últimos dígitos: 4, 2, 6. Suma = 12, múltiplo de 3 → Valido.
#
# ---
#
# ## 4. Ingeniería Comercial — Validador de Códigos de Boletas
#
# ### Introducción
# Estás a cargo del sistema de caja de una pyme y cada boleta emitida tiene un código correlativo que el sistema debe validar antes de registrar la venta.
#
# ### Objetivo
# Verifica que un código de boleta (un int) sea válido: calcula su división entera por **2**, de forma repetida hasta llegar a un número de un solo dígito, y suma los últimos dígitos de cada resultado. Si la suma es múltiplo de **6**, la boleta es válida.
#
# ### Input Format
# Un int con el código de la boleta.
#
# ### Output Format
# Imprime todos los últimos dígitos del procedimiento, y luego 'Valido' o 'Invalido'.
#
# ### Consideraciones
# * El código siempre será un número positivo de dos dígitos o más.
#
# ### Ejemplo 1
# Input
# ```
# 88
# ```
# Output
# ```
# 8
# 4
# 2
# 1
# 5
# Invalido
# ```
# Explicación
# 88 → 44 → 22 → 11 → 5. Últimos dígitos: 8, 4, 2, 1, 5. Suma = 20, no es múltiplo de 6 → Invalido.
#
# ### Ejemplo 2
# Input
# ```
# 24
# ```
# Output
# ```
# 4
# 2
# 6
# Valido
# ```
# Explicación
# 24 → 12 → 6. Últimos dígitos: 4, 2, 6. Suma = 12, múltiplo de 6 → Valido.
