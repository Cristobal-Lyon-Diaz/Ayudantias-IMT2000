# %% [markdown]
# # **Ayudantía 1 - IMT2000**

# %% [markdown]
# ## **Repaso**

# %% [markdown]
# ### **Introducción a Python**

# %% [markdown]
# #### ***Lenguaje de programación*** :
# Idioma para el computador. Ejemplo *Python*, *Java* , *PHP*, etc.

# %% [markdown]
# #### ***Script*** :
# Instrucciones paso a paso

# %% [markdown]
# #### ***Notebook*** :
# Cuaderno interactivo

# %% [markdown]
# #### ***Librería*** :
# Una caja de herramientas pre-hecha que alguien creó para ti

# %% [markdown]
# #### ***Variable*** :
# Un “cajón” con etiqueta donde guardas información
#
# En Python, una variable es un contenedor que se utiliza para almacenar valores. Los valores pueden ser números, cadenas de texto, listas, diccionarios, entre otros tipos de datos.
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
#
# Para crear una variable en Python, es necesario declararla y asignarle un valor. Por ejemplo, para crear una variable llamada "edad" y asignarle el valor de 30, se puede hacer lo siguiente:
#
# ` edad = 30 `
#
# ![image-3.png](attachment:image-3.png)
#
# Las variables tienen sus propias reglas al nombrarlas:
#
# 1. Debe comenzar con _ o con una letra
# 2. Deben evitarse ciertas palabras que estan reservadas por python
#
# Ejemplos válidos:
#
# cristian, pesos_por_hora, _CLaRK, j0rg3
#
#
# Ejemplos NO válidos:
#
# 12deLaNoche, Bruce Wayne, Min+Seg
# ߿and, asset, break, class, continue, def, del, elif, else, except, exec, finally, for,
# from, global, if, import, in, is, lambda, not, or, pass, print, raise, return, try,
# while, field

# %% [markdown]
# #### ***Errores comunes***

# %% [markdown]
# * SyntaxError → escribiste algo mal (un paréntesis, una coma)
# * NameError → usaste un nombre que Python no conoce

# %%
# Ejemplo SyntaxError
print(Hola!)
# Out:
#   Cell In[4], line 2
#     print(Hola!)
#               ^
# SyntaxError: invalid syntax

# %%
# Ejemplo NameError
imprimir("Hola!")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 2
#       1 # Ejemplo NameError
# ----> 2 imprimir("Hola!")
#
# NameError: name 'imprimir' is not defined

# %%
# Caso correcto
print("Hola!")
# Out:
# Hola!

# %% [markdown]
# #### ***Ejecutar*** :
# Correr/hacer funcionar el codigo

# %% [markdown]
# #### ***Tipos de datos*** :
#
# Un tipo de dato es un conjunto de valores
#
# * ***int*** : Enteros (..., -3, -2, -1, 0, 1, 2, 3, ...)
# * ***float*** : Flotantes (decimales reales) (EJ: 3.14, 0.5, 1.2, 2.0)
# * ***str*** : Cadenas (texto) (todo lo que se considera texto) (EJ: "Hola! Que tal", "bnhfuyrehbgfiu4erhyg7845yht4u", "3")
# * ***bool*** : Booleano (Basicamente solo tiene dos posibles valores, **True** y **False** )
#
# Operaciones posibles
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
#
# ![image-3.png](attachment:image-3.png)
#
# ![image-4.png](attachment:image-4.png)
#
# ![image-5.png](attachment:image-5.png)

# %% [markdown]
# #### Imprimir
#
# Imprimir en Python, se refiere a mostrar en pantalla el valor de una variable, es una funcion fundamental en Python.
#
# Por ejemplo, si quiero mostrar en pantalla la sexta potencia de 2, hago lo siguiente:

# %%
# Asigno las variables
dos = 2
seis = 6

# Realizo la operación
sexta_potencia = dos ** seis

# Imprimo el resultado
print(sexta_potencia)
# Out:
# 64

# %%
# No es necesario tanta asignacio, como pueden ver, se puede calcular directamente
otra_forma = 2 ** 6
print(otra_forma)
# Out:
# 64

# %%
# Y pueden apreciar que son iguales
valor_de_verdad = bool(sexta_potencia == otra_forma)
print(valor_de_verdad)
# Out:
# True

# %% [markdown]
# ### **Google Colab**

# %% [markdown]
# #### **Tipos de celda**

# %% [markdown]
# * **Celdas de texto (markdown)** : Para escribir explicaciones, titulos, etc.
#
# * **Celde de código** : Para escribir tu codigo en Python (se ejecuta al presionar el boton de play o con Shift+Enter)

# %% [markdown]
# #### ***Guía markdown***

# %% [markdown]
# En las celdas de texto, uno tiene la opcion de hacer algo más que un simple texto plano, ya sean encabezados, negritas, etc, que hacen mas "bonito" el texto que uno escribe, si bien no se les exigira el uso, les podrá servir para explicar de mejor manera algo.
#
# A continuación les dejare dos celdas, una con el codigo comentado para que no se ejecute y puedan apreciar el codigo, y otra con el codigo ejecutado para que vean como se ve cada cosa.

# %%
"""

# Encabezados
## Encabezado 2
### Encabezado 3
#### Encabezado 4
##### Encabezado 5
###### Encabezado 6

# Listas
- Elemento de lista
* Otro elemento
+ Otro más

1. Primer elemento
2. Segundo elemento

Las **negrita** las *cursivas*. 
***negrita y cursiva***
___Lo mismo___ ~~tachar~~

# Código

`código en una línea`


# Enlaces e imágenes
[Texto del enlace](https://www.ejemplo.com)

<https://www.ejemplo.com>


# Citas
> Esta es una cita.

# Tablas
| Encabezado 1 | Encabezado 2 |
| ------------ | ------------ |
| Celda 1      | Celda 2      |
| Celda 3      | Celda 4      |

# Linea horizontal
Puedes agregar una línea horizontal usando tres o más -, *, o _.

---

***

___

# Lista de tareas
- [ ] Tarea 1
- [x] Tarea 2


"""
# Out:
# '\n\n# Encabezados\n## Encabezado 2\n### Encabezado 3\n#### Encabezado 4\n##### Encabezado 5\n###### Encabezado 6\n\n# Listas\n- Elemento de lista\n* Otro elemento\n+ Otro más\n\n1. Primer elemento\n2. Segundo elemento\n\nLas **negrita** las *cursivas*. \n***negrita y cursiva***\n___Lo mismo___ ~~tachar~~\n\n# Código\n\n`código en una línea`\n\n\n# Enlaces e imágenes\n[Texto del enlace](https://www.ejemplo.com)\n\n<https://www.ejemplo.com>\n\n\n# Citas\n> Esta es una cita.\n\n# Tablas\n| Encabezado 1 | Encabezado 2 |\n| ------------ | ------------ |\n| Celda 1      | Celda 2      |\n| Celda 3      | Celda 4      |\n\n# Linea horizontal\nPuedes agregar una línea horizontal usando tres o más -, *, o _.\n\n---\n\n***\n\n___\n\n# Lista de tareas\n- [ ] Tarea 1\n- [x] Tarea 2\n\n\n'

# %% [markdown]
# # Encabezado 1

# %% [markdown]
# ## Encabezado 2
# ### Encabezado 3
# #### Encabezado 4
# ##### Encabezado 5
# ###### Encabezado 6
#
# ## Listas
# - Elemento de lista
# * Otro elemento
# + Otro más
#
# 1. Primer elemento
# 2. Segundo elemento
#
# Las **negrita** las *cursivas*.
# ***negrita y cursiva***
# ___Lo mismo___ ~~tachar~~
#
# ## Código
#
# `código en una línea`
#
#
# ## Enlaces e imágenes
# [Texto del enlace](https://www.ejemplo.com)
#
# <https://www.ejemplo.com>
#
#
# ## Citas
# > Esta es una cita.
#
# ## Tablas
# | Encabezado 1 | Encabezado 2 |
# | ------------ | ------------ |
# | Celda 1      | Celda 2      |
# | Celda 3      | Celda 4      |
#
# ## Linea horizontal
# Puedes agregar una línea horizontal usando tres o más -, *, o _.
#
# ---
#
# ***
#
# ___
#
# ## Lista de tareas
# - [ ] Tarea 1
# - [x] Tarea 2

# %% [markdown]
# # **Laboratorio 1**

# %% [markdown]
# **Instrucciones** : Deberan crear su propio Jupyter Notebook donde cuenten el porque les intereso este OFG y que esperan de el, además hacer un breve resumen de cualquier materia vista en clases o ayudantías.
#
# La idea es que en el notebook incluyan al menos lo siguiente:
#
# * Celdas de markdown y codigo
# * Uso de negritas y cursivas
# * Links a algun URL
# * 1 Imagen
# * Uso de dos encabezados diferentes
# * Calcular en una celda una operacion matematica compleja e imprimir el resultado
#
# **Entrega** : En Canvas hasta las 23:59 hrs
