# %% [markdown]
# ## La importancia de la limpieza y procesamiento de datos previos: Sentando las bases para un análisis confiable
#
# #### Ayudantia 08 - IMT2000
#
# La limpieza y procesamiento de datos previos son etapas fundamentales en cualquier proyecto de análisis de datos. Estas etapas implican identificar y corregir errores, eliminar valores atípicos y duplicados, y manejar los valores faltantes. Al realizar estas tareas, se garantiza la calidad y confiabilidad de los datos, lo que a su vez mejora la precisión y confiabilidad de los análisis y modelos resultantes. Además, el preprocesamiento de datos permite optimizar el rendimiento de los algoritmos y facilita la interpretación y toma de decisiones basadas en información confiable. En definitiva, la limpieza y procesamiento de datos previos sientan las bases para un análisis confiable y significativo.

# %%
# Importar bibliotecas necesarias
import pandas as pd

# Crear un DataFrame de ejemplo
data = pd.DataFrame({
    'ID': [1, 2, 3, 4, 5],
    'Nombre': ['Juan', 'María', 'Pedro', 'Ana', 'Luisa'],
    'Edad': [25, 30, 35, 28, 42],
    'Altura': [1.75, 1.68, 1.80, 1.62, 1.70],
    'Casado': [False, True, False, True, True]
})

# %%
data
# Out:
#    ID Nombre  Edad  Altura  Casado
# 0   1   Juan    25    1.75   False
# 1   2  María    30    1.68    True
# 2   3  Pedro    35    1.80   False
# 3   4    Ana    28    1.62    True
# 4   5  Luisa    42    1.70    True

# %% [markdown]
# ## 1. Manejo de valores nulos
#
# Es importante identificar y manejar los valores nulos en los conjuntos de datos. Podemos utilizar el método ``isnull()`` para verificar si hay valores nulos en nuestro conjunto de datos y luego usar métodos como ``dropna()`` o ``fillna()`` para manejarlos.

# %%
# Verificar valores nulos
data.isnull().sum()
# Out:
# ID        0
# Nombre    0
# Edad      0
# Altura    0
# Casado    0
# dtype: int64

# %% [markdown]
# ## 2. Eliminación de valores duplicados
#
# Otro paso importante en la limpieza de datos es eliminar los valores duplicados. Podemos utilizar el método ``duplicated()`` para identificar los duplicados y luego usar ``drop_duplicates()`` para eliminarlos.

# %%
# Verificar valores duplicados
data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Otro método útil es el de ``nunique()`` que te entrega el número de elementos únicos de una columna.

# %%
# Verificamos los valores unicos
data.nunique()
# Out:
# ID        5
# Nombre    5
# Edad      5
# Altura    5
# Casado    2
# dtype: int64

# %% [markdown]
# ## 3. Corrección de tipos de datos
#
# A veces, los tipos de datos pueden estar incorrectos en nuestro conjunto de datos. Podemos utilizar métodos como ``astype()`` para convertir los tipos de datos a los apropiados.

# %%
# Convertir tipo de datos de la columna 'Monto_Venta' a float
data['Monto_Venta'] = data['Monto_Venta'].astype(float)

# Verificar los cambios
data.dtypes
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Monto_Venta'
#
# ...

# %% [markdown]
# cada tipo de dato:
#
# - int64: Representa valores enteros. En el ejemplo, la columna "ID" y "Edad" son de tipo entero.
#
# - float64: Representa valores decimales. En el ejemplo, la columna "Altura" es de tipo float.
#
# - object: Representa valores de tipo cadena de texto (strings). En el ejemplo, la columna "Nombre" es de tipo objeto (object).
#
# - bool: Representa valores booleanos (True o False). En el ejemplo, la columna "Casado" es de tipo booleano.
#
# Es importante tener en cuenta los tipos de datos de las columnas en un DataFrame, ya que pueden afectar el análisis y las operaciones que se pueden realizar. En algunos casos, es posible que sea necesario convertir los tipos de datos a otros más apropiados para ciertas operaciones, como convertir cadenas de texto a fechas o números.

# %% [markdown]
# Actividad

# %% [markdown]
# En esta ocación usaremos el dataset de ``imdb_1000.xlx`` el cual contiene el top 1000 de peliculas de la plataforma IMDB: ``https://www.imdb.com``
#
# Recuerda colocarlo en el mismo directorio o carpeta que el archivo jupyter de la ayudantía.
#
# Datos:
#
# - Poster_Link: Enlace al póster utilizado por IMDb.
# - Series_Title: Nombre de la película.
# - Released_Year: Año en que se estrenó la película.
# - Certificate: Certificado obtenido por la película.
# - Runtime: Duración total de la película.
# - Genre: Género de la película.
# - IMDB_Rating: Calificación de la película en el sitio web de IMDb.
# - Overview: Resumen o sinopsis de la película.
# - Meta_score: Puntuación obtenida por la película.
# - Director: Nombre del director.
# - Star1, Star2, Star3, Star4: Nombres de las estrellas (actores/actrices) de la película.
# - No_of_votes: Número total de votos recibidos.
# - Gross: Ganancias monetarias obtenidas por la película.

# %% [markdown]
# * En caso de no haber asistido a ayudantías anteriores, es necesario hacer pip install openpyxl

# %% [markdown]
# 1.Limpieza:
#
# La tarea es que realicen una limpieza correcta de el dataset y procecen los datos de manera que puedan ser bien utlizados para analisis.
#
# El dataset final debe:
#
# - Tener una nueva columna llamada "Top" que diga el número del top de la pelicula.
#
# - No contener filas con valores nulos, excepto las filas que contengan valores nulos en las columnas de "Star" en estas reemplazar el valor nulo por "Nadie" ,elimine el resto de filas del dataframe.
#
# - Tener correcto el tipo de dato que representa la columna, si es numerico, string u otro.
#
# - El nombre de las columnas debe ser descriptivo, en español, y sin espacios. Se recomienda usar el "_" para representar espacios.
#
# - Eliminar las columnas de "Certificate" y "Meta_score", ya que, no son relevantes para el analisis.

# %%
# -----------------------------
data = pd.read_excel("imdb_1000.xlsx")
data.head()
# Out:
#                                          Poster_Link  \
# 0  https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1  https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2  https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3  https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4  https://m.media-amazon.com/images/M/MV5BMWU4N2...
#
#                Series_Title Released_Year Certificate  Runtime  \
# 0  The Shawshank Redemption          1994           A  142 min
# 1             The Godfather          1972           A  175 min
# 2           The Dark Knight          2008          UA  152 min
# 3    The Godfather: Part II          1974           A  202 min
# 4              12 Angry Men          1957           U   96 min
#
#                   Genre  IMDB_Rating  \
# 0                 Drama          9.3
# 1          Crime, Drama          9.2
# 2  Action, Crime, Drama          9.0
# 3          Crime, Drama          9.0
# 4          Crime, Drama          9.0
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Poster_Link    1000 non-null   object
#  1   Series_Title   1000 non-null   object
#  2   Released_Year  1000 non-null   object
#  3   Certificate    899 non-null    object
#  4   Runtime        1000 non-null   object
#  5   Genre          1000 non-null   object
#  6   IMDB_Rating    1000 non-null   float64
#  7   Overview       1000 non-null   object
#  8   Meta_score     843 non-null    float64
#  9   Director       1000 non-null   object
#  10  Star1          1000 non-null   object
#  11  Star2          1000 non-null   object
#  12  Star3          985 non-null    object
#  13  Star4          990 non-null    object
#  14  No_of_Votes    1000 non-null   int64
#  15  Gross          831 non-null    object
# dtypes: float64(2), int64(1), object(13)
# memory usage: 125.1+ KB

# %% [markdown]
# ## Columna TOP

# %%
df = data.copy()

# %%
df.sort_values(by="IMDB_Rating", ascending=False, inplace=True)

# %%
df
# Out:
#                                            Poster_Link  \
# 0    https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1    https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2    https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3    https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4    https://m.media-amazon.com/images/M/MV5BMWU4N2...
# ..                                                 ...
# 912  https://m.media-amazon.com/images/M/MV5BMTU5MD...
# 911  https://m.media-amazon.com/images/M/MV5BYmFmNj...
# 910  https://m.media-amazon.com/images/M/MV5BMjAxOT...
# 909  https://m.media-amazon.com/images/M/MV5BMjI2OD...
# 999  https://m.media-amazon.com/images/M/MV5BMTY5OD...
#
#                  Series_Title Released_Year Certificate  Runtime  \
# 0    The Shawshank Redemption          1994           A  142 min
# 1               The Godfather          1972           A  175 min
# 2             The Dark Knight          2008          UA  152 min
# ...

# %%
top = list(range(1, 1001))
df["Top"] = top
df["Top"]
# Out:
# 0         1
# 1         2
# 2         3
# 3         4
# 4         5
#        ...
# 912     996
# 911     997
# 910     998
# 909     999
# 999    1000
# Name: Top, Length: 1000, dtype: int64

# %%
df.head(5)
# Out:
#                                          Poster_Link  \
# 0  https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1  https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2  https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3  https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4  https://m.media-amazon.com/images/M/MV5BMWU4N2...
#
#                Series_Title Released_Year Certificate  Runtime  \
# 0  The Shawshank Redemption          1994           A  142 min
# 1             The Godfather          1972           A  175 min
# 2           The Dark Knight          2008          UA  152 min
# 3    The Godfather: Part II          1974           A  202 min
# 4              12 Angry Men          1957           U   96 min
#
#                   Genre  IMDB_Rating  \
# 0                 Drama          9.3
# 1          Crime, Drama          9.2
# 2  Action, Crime, Drama          9.0
# 3          Crime, Drama          9.0
# 4          Crime, Drama          9.0
#
# ...

# %% [markdown]
# ## Eliminar filas nulas fuera de "Star"

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Poster_Link    1000 non-null   object
#  1   Series_Title   1000 non-null   object
#  2   Released_Year  1000 non-null   object
#  3   Certificate    899 non-null    object
#  4   Runtime        1000 non-null   object
#  5   Genre          1000 non-null   object
#  6   IMDB_Rating    1000 non-null   float64
#  7   Overview       1000 non-null   object
#  8   Meta_score     843 non-null    float64
#  9   Director       1000 non-null   object
#  10  Star1          1000 non-null   object
#  11  Star2          1000 non-null   object
#  12  Star3          985 non-null    object
#  13  Star4          990 non-null    object
#  14  No_of_Votes    1000 non-null   int64
#  15  Gross          831 non-null    object
#  16  Top            1000 non-null   int64
# ...

# %%
df["Star3"].fillna("Nadie", inplace=True)
df["Star4"].fillna("Nadie", inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Poster_Link    1000 non-null   object
#  1   Series_Title   1000 non-null   object
#  2   Released_Year  1000 non-null   object
#  3   Certificate    899 non-null    object
#  4   Runtime        1000 non-null   object
#  5   Genre          1000 non-null   object
#  6   IMDB_Rating    1000 non-null   float64
#  7   Overview       1000 non-null   object
#  8   Meta_score     843 non-null    float64
#  9   Director       1000 non-null   object
#  10  Star1          1000 non-null   object
#  11  Star2          1000 non-null   object
#  12  Star3          1000 non-null   object
#  13  Star4          1000 non-null   object
#  14  No_of_Votes    1000 non-null   int64
#  15  Gross          831 non-null    object
#  16  Top            1000 non-null   int64
# ...

# %%
df.dropna(inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 714 entries, 0 to 910
# Data columns (total 17 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Poster_Link    714 non-null    object
#  1   Series_Title   714 non-null    object
#  2   Released_Year  714 non-null    object
#  3   Certificate    714 non-null    object
#  4   Runtime        714 non-null    object
#  5   Genre          714 non-null    object
#  6   IMDB_Rating    714 non-null    float64
#  7   Overview       714 non-null    object
#  8   Meta_score     714 non-null    float64
#  9   Director       714 non-null    object
#  10  Star1          714 non-null    object
#  11  Star2          714 non-null    object
#  12  Star3          714 non-null    object
#  13  Star4          714 non-null    object
#  14  No_of_Votes    714 non-null    int64
#  15  Gross          714 non-null    object
#  16  Top            714 non-null    int64
# ...

# %% [markdown]
# Buscamos información para completar el dataframe

# %%
df[df["Released_Year"] == "PG"]
# Out:
#                                            Poster_Link Series_Title  \
# 966  https://m.media-amazon.com/images/M/MV5BNjEzYj...    Apollo 13
#
#     Released_Year Certificate  Runtime                      Genre  \
# 966            PG           U  140 min  Adventure, Drama, History
#
#      IMDB_Rating                                           Overview  \
# 966          7.6  NASA must devise a strategy to return Apollo 1...
#
#      Meta_score    Director      Star1        Star2        Star3        Star4  \
# 966        77.0  Ron Howard  Tom Hanks  Bill Paxton  Kevin Bacon  Gary Sinise
#
#      No_of_Votes         Gross  Top
# 966       269197  $173,837,933  890

# %%
df.reset_index(inplace=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [40], in <cell line: 1>()
# ----> 1 df.reset_index(inplace=True)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:5833, in DataFrame.reset_index(self, level, drop, inplace, col_level, col_fill)
#    5827         if lab is not None:
#    5828             # if we have the codes, extract the values with a mask
# ...

# %%
df = df.drop(columns=["level_0", "index"], axis=1)

# %%
df[df["Released_Year"] == "PG"]
# Out:
#                                            Poster_Link Series_Title  \
# 618  https://m.media-amazon.com/images/M/MV5BNjEzYj...    Apollo 13
#
#     Released_Year Certificate  Runtime                      Genre  \
# 618            PG           U  140 min  Adventure, Drama, History
#
#      IMDB_Rating                                           Overview  \
# 618          7.6  NASA must devise a strategy to return Apollo 1...
#
#      Meta_score    Director      Star1        Star2        Star3        Star4  \
# 618        77.0  Ron Howard  Tom Hanks  Bill Paxton  Kevin Bacon  Gary Sinise
#
#      No_of_Votes         Gross  Top
# 618       269197  $173,837,933  890

# %%
df.at[618, "Released_Year"] = 1995
df.iloc[618, :]
# Out:
# Poster_Link      https://m.media-amazon.com/images/M/MV5BNjEzYj...
# Series_Title                                             Apollo 13
# Released_Year                                                 1995
# Certificate                                                      U
# Runtime                                                    140 min
# Genre                                    Adventure, Drama, History
# IMDB_Rating                                                    7.6
# Overview         NASA must devise a strategy to return Apollo 1...
# Meta_score                                                    77.0
# Director                                                Ron Howard
# Star1                                                    Tom Hanks
# Star2                                                  Bill Paxton
# Star3                                                  Kevin Bacon
# Star4                                                  Gary Sinise
# ...

# %%
df["Series_Title"] = df["Series_Title"].astype(str)
df["Released_Year"] = df["Released_Year"].astype(int)
df["Gross"] = df["Gross"].astype(str)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 714 entries, 0 to 713
# Data columns (total 17 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Poster_Link    714 non-null    object
#  1   Series_Title   714 non-null    object
#  2   Released_Year  714 non-null    int32
#  3   Certificate    714 non-null    object
#  4   Runtime        714 non-null    object
#  5   Genre          714 non-null    object
#  6   IMDB_Rating    714 non-null    float64
#  7   Overview       714 non-null    object
#  8   Meta_score     714 non-null    float64
#  9   Director       714 non-null    object
#  10  Star1          714 non-null    object
#  11  Star2          714 non-null    object
#  12  Star3          714 non-null    object
#  13  Star4          714 non-null    object
#  14  No_of_Votes    714 non-null    int64
#  15  Gross          714 non-null    object
#  16  Top            714 non-null    int64
# ...

# %%
columnas = ["nombre_pelicula", "lanzamiento", "Certificado", "Duracion", "Genero"]
df = df.rename(columns = {"Series_Title": "nombre_pelicula", 
                          "Released_Year": "lanzamiento", 
                          "Certificate": "Certificado", "Runtime": "Duracion",
                         "Genre": "Genero"})

df.columns
# Out:
# Index(['Poster_Link', 'nombre_pelicula', 'lanzamiento', 'Certificado',
#        'Duracion', 'Genero', 'IMDB_Rating', 'Overview', 'Meta_score',
#        'Director', 'Star1', 'Star2', 'Star3', 'Star4', 'No_of_Votes', 'Gross',
#        'Top'],
#       dtype='object')

# %%
df.drop(columns=["Certificado", "Meta_score"], axis=1, inplace=True)

# %%
df
# Out:
#                                            Poster_Link  \
# 0    https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1    https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2    https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3    https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4    https://m.media-amazon.com/images/M/MV5BMWU4N2...
# ..                                                 ...
# 709  https://m.media-amazon.com/images/M/MV5BMjEzOT...
# 710  https://m.media-amazon.com/images/M/MV5BMTg0Nj...
# 711  https://m.media-amazon.com/images/M/MV5BMTU5MD...
# 712  https://m.media-amazon.com/images/M/MV5BYmFmNj...
# 713  https://m.media-amazon.com/images/M/MV5BMjAxOT...
#
#               nombre_pelicula  lanzamiento Duracion  \
# 0    The Shawshank Redemption         1994  142 min
# 1               The Godfather         1972  175 min
# 2             The Dark Knight         2008  152 min
# 3      The Godfather: Part II         1974  202 min
# ...

# %% [markdown]
# 2.Analisis:
#
# - Muestren es la pelicula más vieja del top y en qué top está.
#
# - Muestren el director que tiene más peliculas en el top.
#
# - Muestren el promedio de los tiempos de duración de todas las peliculas que tenga cada director.
#
# - Tomen su director favorito y muestren un analisis de su crítica y taquilla, es decir, obtener en un unico dataframe la mejor y peor pelicula según el ranking IMDB y otro dataframe que muestre la pelicula que haya tenido mayor y menor ganancias.

# %%
df1 = df.copy()

# %%
df1.sort_values(by="lanzamiento", inplace=True)
# Como ordenamos el dataframe, la primera fila, será la película más vieja.

df1.iloc[0, -1]
# Out:
# 373

# %%
df1.iloc[0, :]
# Out:
# Poster_Link        https://m.media-amazon.com/images/M/MV5BMzg2MW...
# nombre_pelicula                       All Quiet on the Western Front
# lanzamiento                                                     1930
# Duracion                                                     152 min
# Genero                                                    Drama, War
# IMDB_Rating                                                      8.0
# Overview           A German youth eagerly enters World War I, but...
# Director                                             Lewis Milestone
# Star1                                                      Lew Ayres
# Star2                                                  Louis Wolheim
# Star3                                                      John Wray
# Star4                                                    Arnold Lucy
# No_of_Votes                                                    57318
# Gross                                                     $3,270,000
# ...

# %% [markdown]
# ## Director con más peliculas

# %%
df1.groupby(by="Director").count()["Top"].sort_values()
# Out:
# Director
# Abdellatif Kechiche     1
# Merian C. Cooper        1
# Mel Stuart              1
# Matt Ross               1
# Matt Reeves             1
#                        ..
# David Fincher           8
# Quentin Tarantino       8
# Alfred Hitchcock        9
# Martin Scorsese        10
# Steven Spielberg       13
# Name: Top, Length: 402, dtype: int64

# %% [markdown]
# # Promedios duración

# %%
df1["Duracion"] = df1["Duracion"].apply(lambda x: x.rstrip(" min")).astype(int)

# %%
df1.head(2)
# Out:
#                                            Poster_Link  \
# 240  https://m.media-amazon.com/images/M/MV5BMzg2MW...
# 32   https://m.media-amazon.com/images/M/MV5BY2I4Mm...
#
#                     nombre_pelicula  lanzamiento  Duracion  \
# 240  All Quiet on the Western Front         1930       152
# 32                      City Lights         1931        87
#
#                      Genero  IMDB_Rating  \
# 240              Drama, War          8.0
# 32   Comedy, Drama, Romance          8.5
#
#                                               Overview         Director  \
# 240  A German youth eagerly enters World War I, but...  Lewis Milestone
# 32   With the aid of a wealthy erratic tippler, a d...  Charles Chaplin
#
#                Star1              Star2         Star3        Star4  \
# 240        Lew Ayres      Louis Wolheim     John Wray  Arnold Lucy
# 32   Charles Chaplin  Virginia Cherrill  Florence Lee  Harry Myers
#
#      No_of_Votes       Gross  Top
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 714 entries, 240 to 685
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Poster_Link      714 non-null    object
#  1   nombre_pelicula  714 non-null    object
#  2   lanzamiento      714 non-null    int32
#  3   Duracion         714 non-null    int32
#  4   Genero           714 non-null    object
#  5   IMDB_Rating      714 non-null    float64
#  6   Overview         714 non-null    object
#  7   Director         714 non-null    object
#  8   Star1            714 non-null    object
#  9   Star2            714 non-null    object
#  10  Star3            714 non-null    object
#  11  Star4            714 non-null    object
#  12  No_of_Votes      714 non-null    int64
#  13  Gross            714 non-null    object
#  14  Top              714 non-null    int64
# dtypes: float64(1), int32(2), int64(2), object(10)
# memory usage: 83.7+ KB

# %%
df1.groupby(by="Director").mean()["Duracion"]
# Out:
# Director
# Abdellatif Kechiche    180.0
# Abhishek Kapoor        130.0
# Adam McKay             130.0
# Akira Kurosawa         184.5
# Alan J. Pakula         138.0
#                        ...
# Yimou Zhang            120.0
# Yoshiaki Kawajiri      103.0
# Yôjirô Takita          130.0
# Zack Snyder            139.5
# Zoya Akhtar            154.0
# Name: Duracion, Length: 402, dtype: float64

# %% [markdown]
# # Crítica

# %%
# Elegir un director, ver su mejor y peor película según ranking IMDB, ver la con más y menos ganancias

df2 = df1[df1["Director"] == "Steven Spielberg"]
df2
# Out:
#                                            Poster_Link  \
# 207  https://m.media-amazon.com/images/M/MV5BMmVmOD...
# 645  https://m.media-amazon.com/images/M/MV5BMjM1Nj...
# 49   https://m.media-amazon.com/images/M/MV5BMjA0OD...
# 419  https://m.media-amazon.com/images/M/MV5BMTQ2OD...
# 409  https://m.media-amazon.com/images/M/MV5BZDRkOW...
# 495  https://m.media-amazon.com/images/M/MV5BMmQwNz...
# 106  https://m.media-amazon.com/images/M/MV5BMjNkMz...
# 7    https://m.media-amazon.com/images/M/MV5BNDE4OT...
# 150  https://m.media-amazon.com/images/M/MV5BMjM2MD...
# 28   https://m.media-amazon.com/images/M/MV5BZjhkMD...
# 194  https://m.media-amazon.com/images/M/MV5BMTY5Mz...
# 623  https://m.media-amazon.com/images/M/MV5BZTI3Yz...
# 676  https://m.media-amazon.com/images/M/MV5BMjIxOT...
#
#                         nombre_pelicula  lanzamiento  Duracion  \
# 207                                Jaws         1975       124
# ...

# %%
df_ranking = df2.copy()
df_money = df2.copy()

# %%
# Ranking

df_ranking.sort_values(by="IMDB_Rating", inplace=True)

# %%
df_ranking.reset_index(inplace=True)

# %%
df_ranking = df_ranking.iloc[[0,-1],:]
df_ranking
# Out:
#     index                                        Poster_Link  \
# 0     645  https://m.media-amazon.com/images/M/MV5BMjM1Nj...
# 12      7  https://m.media-amazon.com/images/M/MV5BNDE4OT...
#
#                        nombre_pelicula  lanzamiento  Duracion  \
# 0   Close Encounters of the Third Kind         1977       138
# 12                    Schindler's List         1993       195
#
#                        Genero  IMDB_Rating  \
# 0               Drama, Sci-Fi          7.6
# 12  Biography, Drama, History          8.9
#
#                                              Overview          Director  \
# 0   Roy Neary, an electric lineman, watches how hi...  Steven Spielberg
# 12  In German-occupied Poland during World War II,...  Steven Spielberg
#
#                Star1              Star2         Star3             Star4  \
# 0   Richard Dreyfuss  François Truffaut     Teri Garr    Melinda Dillon
# 12       Liam Neeson      Ralph Fiennes  Ben Kingsley  Caroline Goodall
#
# ...

# %% [markdown]
# # Ganancias

# %%
df_money["Gross"] = df_money["Gross"].apply(lambda x: x.lstrip("$").replace(",", "")).astype(int)
df_money.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13 entries, 207 to 676
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Poster_Link      13 non-null     object
#  1   nombre_pelicula  13 non-null     object
#  2   lanzamiento      13 non-null     int32
#  3   Duracion         13 non-null     int32
#  4   Genero           13 non-null     object
#  5   IMDB_Rating      13 non-null     float64
#  6   Overview         13 non-null     object
#  7   Director         13 non-null     object
#  8   Star1            13 non-null     object
#  9   Star2            13 non-null     object
#  10  Star3            13 non-null     object
#  11  Star4            13 non-null     object
#  12  No_of_Votes      13 non-null     int64
#  13  Gross            13 non-null     int32
#  14  Top              13 non-null     int64
# dtypes: float64(1), int32(3), int64(2), object(9)
# memory usage: 1.5+ KB

# %%
df_money.sort_values(by="Gross", inplace=True)

# %%
df_money.reset_index(inplace=True)

# %%
df_money = df_money.iloc[[0,-1], :]
df_money
# Out:
#     index                                        Poster_Link  \
# 0     495  https://m.media-amazon.com/images/M/MV5BMmQwNz...
# 12    419  https://m.media-amazon.com/images/M/MV5BMTQ2OD...
#
#                nombre_pelicula  lanzamiento  Duracion                  Genero  \
# 0            Empire of the Sun         1987       153  Action, Drama, History
# 12  E.T. the Extra-Terrestrial         1982       115          Family, Sci-Fi
#
#     IMDB_Rating                                           Overview  \
# 0           7.7  A young English boy struggles to survive under...
# 12          7.8  A troubled child summons the courage to help a...
#
#             Director           Star1           Star2               Star3  \
# 0   Steven Spielberg  Christian Bale  John Malkovich  Miranda Richardson
# 12  Steven Spielberg    Henry Thomas  Drew Barrymore        Peter Coyote
#
#            Star4  No_of_Votes      Gross  Top
# 0   Nigel Havers       115677   22238696  732
# ...
